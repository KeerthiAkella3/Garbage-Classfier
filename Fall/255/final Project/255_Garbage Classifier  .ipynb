# %% [markdown]
# # Garbage Classifier

# %% [markdown]
# ### Pre Processing

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img
from keras.layers import Conv2D, Flatten, MaxPooling2D, Dense
from keras.models import Sequential

import glob, os, random
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Do anyone know how to set below path using "__dirname"

# %%
basePath = '/Users/Keerthy/Desktop/Fall/255/final Project/garbage-classification/Garbage classification/Garbage classification'

# %% [markdown]
# glob returns the list of files with their full path

# %%
imgList = glob.glob(os.path.join(basePath, '*/*.jpg'))
print(len(imgList))
# Out:
# 2527

# %%
print(imgList).head
# Out:
# ['/Users/Keerthy/Desktop/Fall/255/final Project/garbage-classification/Garbage classification/Garbage classification/paper/paper283.jpg', '/Users/Keerthy/Desktop/Fall/255/final Project/garbage-classification/Garbage classification/Garbage classification/paper/paper297.jpg', '/Users/Keerthy/Desktop/Fall/255/final Project/garbage-classification/Garbage classification/Garbage classification/paper/paper526.jpg', '/Users/Keerthy/Desktop/Fall/255/final Project/garbage-classification/Garbage classification/Garbage classification/paper/paper240.jpg', '/Users/Keerthy/Desktop/Fall/255/final Project/garbage-classification/Garbage classification/Garbage classification/paper/paper254.jpg', '/Users/Keerthy/Desktop/Fall/255/final Project/garbage-classification/Garbage classification/Garbage classification/paper/paper532.jpg', '/Users/Keerthy/Desktop/Fall/255/final Project/garbage-classification/Garbage classification/Garbage classification/paper/paper268.jpg', '/Users/Keerthy/Desktop/Fall/255/final
# ...

# %% [markdown]
# ## K-means
